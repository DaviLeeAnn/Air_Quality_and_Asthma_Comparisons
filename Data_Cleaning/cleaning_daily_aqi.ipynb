# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
daily_aqi = pd.read_csv('../Data/daily_aqi_by_county_2022.csv')
print(daily_aqi.shape)
daily_aqi.head()
# Out:
# (324419, 10)
#   State Name county Name  State Code  County Code        Date  AQI  Category  \
# 0    Alabama     Baldwin           1            3  2022-01-02   29      Good
# 1    Alabama     Baldwin           1            3  2022-01-05   48      Good
# 2    Alabama     Baldwin           1            3  2022-01-08   47      Good
# 3    Alabama     Baldwin           1            3  2022-01-11   21      Good
# 4    Alabama     Baldwin           1            3  2022-01-14   56  Moderate
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1

# %%
daily_aqi.columns
# Out:
# Index(['State Name', 'county Name', 'State Code', 'County Code', 'Date', 'AQI',
#        'Category', 'Defining Parameter', 'Defining Site',
#        'Number of Sites Reporting'],
#       dtype='str')

# %%
#Renaming a few columns for easier access
daily_aqi.rename(columns={'State Name': 'State', 'county Name': 'County', 'Category': 'AQI Category'}, inplace=True)

# %%
daily_aqi.isna()
daily_aqi.isna().sum()
# Out:
# State                        0
# County                       0
# State Code                   0
# County Code                  0
# Date                         0
# AQI                          0
# AQI Category                 0
# Defining Parameter           0
# Defining Site                0
# Number of Sites Reporting    0
# dtype: int64

# %%
daily_aqi.isnull().sum()
# Out:
# State                        0
# County                       0
# State Code                   0
# County Code                  0
# Date                         0
# AQI                          0
# AQI Category                 0
# Defining Parameter           0
# Defining Site                0
# Number of Sites Reporting    0
# dtype: int64

# %%
daily_aqi.duplicated().sum()
# Out:
# np.int64(0)

# %%
daily_aqi.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 324419 entries, 0 to 324418
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      324419 non-null  str
#  1   County                     324419 non-null  str
#  2   State Code                 324419 non-null  int64
#  3   County Code                324419 non-null  int64
#  4   Date                       324419 non-null  str
#  5   AQI                        324419 non-null  int64
#  6   AQI Category               324419 non-null  str
#  7   Defining Parameter         324419 non-null  str
#  8   Defining Site              324419 non-null  str
#  9   Number of Sites Reporting  324419 non-null  int64
# dtypes: int64(4), str(6)
# memory usage: 24.8 MB

# %%
#Dropping unneeded or unneccessary columns
daily_aqi.drop(columns=['State Code', 'County Code', 'Defining Parameter', 'Defining Site'], inplace=True)

# %%
daily_aqi.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 324419 entries, 0 to 324418
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   State         324419 non-null  str
#  1   County        324419 non-null  str
#  2   Date          324419 non-null  str
#  3   AQI           324419 non-null  int64
#  4   AQI Category  324419 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 12.4 MB

# %%
#Missed a value, so I'll go ahead and drop that last one I don't need
daily_aqi.drop(columns=['Number of Sites Reporting'], inplace=True)

# %%
print(daily_aqi.describe())
# Out:
#                  AQI
# count  324419.000000
# mean       42.147904
# std        29.887421
# min         0.000000
# 25%        31.000000
# 50%        41.000000
# 75%        51.000000
# max      8368.000000

# %%
#Again, boolean indexing to filter for Kentucky AQI data
ky_aqi_boolean = daily_aqi['State'] == 'Kentucky'
ky_aqi_boolean
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 324414    False
# 324415    False
# 324416    False
# 324417    False
# 324418    False
# Name: State, Length: 324419, dtype: bool

# %%
#Drop all rows where the boolean is false, leaving only Kentucky AQI data
ky_aqi = daily_aqi[ky_aqi_boolean]
print(ky_aqi)
# Out:
#            State      County        Date  AQI AQI Category
# 104186  Kentucky        Bell  2022-01-01   36         Good
# 104187  Kentucky        Bell  2022-01-02    9         Good
# 104188  Kentucky        Bell  2022-01-03   25         Good
# 104189  Kentucky        Bell  2022-01-04   49         Good
# 104190  Kentucky        Bell  2022-01-05   55     Moderate
# ...          ...         ...         ...  ...          ...
# 112351  Kentucky  Washington  2022-12-27   31         Good
# 112352  Kentucky  Washington  2022-12-28   38         Good
# 112353  Kentucky  Washington  2022-12-29   39         Good
# 112354  Kentucky  Washington  2022-12-30   39         Good
# 112355  Kentucky  Washington  2022-12-31   29         Good
#
# [8170 rows x 5 columns]

# %%
#Consolidating the dataframe for county level data, which is what I need for my analysis. I only need Fayette, Pulaski, Pike, and Warren counties
counties_of_interest = ['Fayette', 'Pulaski', 'Pike', 'Warren']
ky_aqi_counties = ky_aqi[ky_aqi['County'].isin(counties_of_interest)]
print(ky_aqi_counties)
# Out:
#            State   County        Date  AQI AQI Category
# 107172  Kentucky  Fayette  2022-01-01   22         Good
# 107173  Kentucky  Fayette  2022-01-02   25         Good
# 107174  Kentucky  Fayette  2022-01-03   36         Good
# 107175  Kentucky  Fayette  2022-01-04   41         Good
# 107176  Kentucky  Fayette  2022-01-05   32         Good
# ...          ...      ...         ...  ...          ...
# 111987  Kentucky   Warren  2022-12-27   60     Moderate
# 111988  Kentucky   Warren  2022-12-28   52     Moderate
# 111989  Kentucky   Warren  2022-12-29   37         Good
# 111990  Kentucky   Warren  2022-12-30   42         Good
# 111991  Kentucky   Warren  2022-12-31   25         Good
#
# [1452 rows x 5 columns]
